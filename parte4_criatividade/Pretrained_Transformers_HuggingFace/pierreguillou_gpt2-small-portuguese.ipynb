# %% [markdown]
# <a href="https://colab.research.google.com/github/luiscunhacsc/udemy-ia-pt/blob/main/pierreguillou_gpt2-small-portuguese.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Suprimir avisos
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# Instalar as bibliotecas necessárias com menos verbosidade
# !pip install -q transformers torch

# Carregar o modelo e o tokenizer ajustado para português
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch

model_name = 'pierreguillou/gpt2-small-portuguese'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name).to('cuda')

import time

def generate_text(prompt, model, tokenizer, max_length=500, temperature=0.7):
    inputs = tokenizer.encode(prompt, return_tensors='pt').to('cuda')
    attention_mask = torch.ones(inputs.shape, dtype=torch.long).to('cuda')

    # Medir o tempo de geração
    start_time = time.time()
    outputs = model.generate(inputs,
                             attention_mask=attention_mask,
                             max_length=max_length,
                             temperature=temperature,
                             num_return_sequences=1,
                             do_sample=True,
                             top_k=50,
                             pad_token_id=tokenizer.eos_token_id)  # Definir explicitamente o pad_token_id
    end_time = time.time()

    text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    generation_time = end_time - start_time

    return text, generation_time

# Prompt inicial
prompt = "Era uma vez em uma pequena vila"

# Geração com diferentes temperaturas
for temp in [0.2, 0.7, 1.0]:
    print(f"\n--- Narrativa com temperatura {temp} ---")
    narrative, gen_time = generate_text(prompt, model, tokenizer, temperature=temp)
    print(f"Tempo de geração: {gen_time:.2f} segundos")
    print(narrative)
# Out:
# --- Narrativa com temperatura 0.2 ---
# Tempo de geração: 5.53 segundos
# Era uma vez em uma pequena vila, no centro da cidade, onde se encontra a Igreja Matriz.
#
# A Igreja Matriz de Nossa Senhora da Conceição de Vila Nova de Gaia, construída em 1539, foi tombada pelo Instituto do Patrimônio Histórico e Artístico Nacional (IPHAN) em 1984.
#
# A Igreja Matriz de Nossa Senhora da Conceição de Vila Nova de Gaia foi tombada pelo IPHAN em 1984.
#
# A Igreja Matriz de Nossa Senhora da Conceição de Vila Nova de Gaia foi tombada pelo Instituto do Patrimônio Histórico e Artístico Nacional (IPHAN) em 1984.
#
# A Igreja Matriz de Nossa Senhora da Conceição de Vila Nova de Gaia foi tombada pelo IPHAN em 1984.
#
# A Igreja Matriz de Nossa Senhora da Conceição de Vila Nova de Gaia foi tombada pelo IPHAN em 1984.
#
# A Igreja Matriz de Nossa Senhora da Conceição de Vila Nova de Gaia foi tombada pelo IPHAN em 1984.
#
# ...
