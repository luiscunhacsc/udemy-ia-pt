# %% [markdown]
# <a href="https://colab.research.google.com/github/luiscunhacsc/udemy-ia-pt/blob/main/EleutherAI_gpt-neo-2.7B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Suprimir avisos (para tornar saída mais limpa)
# Estamos a usar modelos públicos, pelo que não é preciso autenticar-nos
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
# Instalar as bibliotecas necessárias
# !pip install -q transformers torch
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 28.3 MB/s eta 0:00:00

# %%
# Carregar o modelo e o tokenizer
from transformers import GPTNeoForCausalLM, GPT2Tokenizer
import torch

model_name = 'EleutherAI/gpt-neo-2.7B'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPTNeoForCausalLM.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.46k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/10.7G [00:00<?, ?B/s]

# %%
# Geração de texto


def generate_text(prompt, model, tokenizer, max_length=200, temperature=0.7):
    # Tokenizar o prompt
    inputs = tokenizer.encode(prompt, return_tensors='pt')

    # Criar a attention mask
    attention_mask = torch.ones(inputs.shape, dtype=torch.long)

    # Gerar texto a partir do modelo
    outputs = model.generate(inputs,
                             attention_mask=attention_mask,
                             max_length=max_length,
                             temperature=temperature,
                             num_return_sequences=1,
                             do_sample=True,
                             top_k=50,
                             pad_token_id=tokenizer.eos_token_id)

    # Decodificar o texto gerado
    text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return text

# Prompt inicial
prompt = "Era uma vez em uma pequena vila"

# Geração com diferentes temperaturas
for temp in [0.2, 0.7, 1.0]:
    print(f"\n--- Narrativa com temperatura {temp} ---")
    narrative = generate_text(prompt, model, tokenizer, temperature=temp)
    print(narrative)
# Out:
# --- Narrativa com temperatura 0.2 ---
# Era uma vez em uma pequena vila do interior de São Paulo, no litoral paulista, onde um homem de cabelo castanho e olhos castanhos, com um cabelo escuro e um nariz de pau, como se fosse um gato, se ajoelhava no banco de trás de um carro e falava com um homem de cabelo castanho e olhos castanhos, como se fosse um gato, se ajoelhava no banco de trás de um carro e falava com um homem de cabelo castanho e olhos castanhos, como se fosse um gato, se ajoelhava no banco de trás de um carro e falava com um homem de cabelo
#
# --- Narrativa com temperatura 0.7 ---
# Era uma vez em uma pequena vila do interior da Grande Paris, no Algarve. Foi um dia onde as pessoas tinham mais amor no mundo.
#
# As pessoas sabiam que era uma coisa muito especial, mas que não se podia dizer. O pobre que não conseguia mais ser pobre, e que não conseguia mais seguir o seu caminho, era um homem com muitos amores.
#
# Era um homem com ou sem filhos. Um homem que tinha mais amor no mundo.
#
# Era um homem que se esforçava pela sua comédia e pelo seu humor. Um homem que não podia mais ser pobre.
#
# --- Narrativa com temperatura 1.0 ---
# Era uma vez em uma pequena vila da Londres no inverno de 1951, quando ele foi encontrado oito semanas para ser executado. Fiquei impressionada quando encontrou a maldição antes de meio dia. Não havia muita gente lá. O médico que apareceu era cabeçudo de pés de nove anos, e, como sempre fazia, me perguntou se eu gostaria de vir ao hospital “materno’. Não ia, e não me deixaram ir tampouco porque eles sabiam. Também não encontro vida depois da morte. Tinha uma bênção e, depois, senti uma sensação mais
